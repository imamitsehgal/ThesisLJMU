# %%
from nsepy import get_history as gh
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

# %%
# !pip install nsepy
# Out:
# Requirement already satisfied: nsepy in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (0.8)
# Requirement already satisfied: pandas in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from nsepy) (1.2.4)
# Requirement already satisfied: six in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from nsepy) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from nsepy) (4.9.3)
# Requirement already satisfied: click in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from nsepy) (7.1.2)
# Requirement already satisfied: numpy in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from nsepy) (1.20.1)
# Requirement already satisfied: requests in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from nsepy) (2.25.1)
# Requirement already satisfied: lxml in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from nsepy) (4.6.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->nsepy) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from pandas->nsepy) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from pandas->nsepy) (2021.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from requests->nsepy) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from requests->nsepy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from requests->nsepy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/rajatmishra/anaconda3/lib/python3.8/site-packages (from requests->nsepy) (2.10)

# %%
start = dt.datetime(2013,1,1)
end = dt.datetime(2018,12,31)
stk_data = gh(symbol='BANKNIFTY',start=start,end=end, index=True)
stk_data.head()
# Out:
#                 Open      High       Low     Close      Volume      Turnover
# Date
# 2013-01-01  12549.95  12663.50  12547.15  12654.15  14463771.0  1.251210e+10
# 2013-01-02  12748.85  12811.45  12748.85  12786.85  19173502.0  1.576190e+10
# 2013-01-03  12828.30  12837.80  12722.45  12778.15  15299267.0  1.400810e+10
# 2013-01-04  12774.80  12801.70  12684.65  12787.35  14247498.0  1.308190e+10
# 2013-01-07  12837.45  12837.45  12682.80  12708.70  15376488.0  1.211380e+10

# %%
plt.figure(figsize=(14,14))
plt.plot(stk_data['Close'])
plt.title('Historical Stock Value')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.show()

# %%
#Data Preprocessing
stk_data['Date'] = stk_data.index
data2 = pd.DataFrame(columns = ['Date', 'Open', 'High', 'Low', 'Close'])
data2['Date'] = stk_data['Date']
data2['Open'] = stk_data['Open']
data2['High'] = stk_data['High']
data2['Low'] = stk_data['Low']
data2['Close'] = stk_data['Close']
train_set = data2.iloc[:, 1:2].values
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(train_set)

training_set_scaled
# Out:
# array([[0.19609217],
#        [0.20619311],
#        [0.21022789],
#        ...,
#        [0.94011299],
#        [0.93238113],
#        [0.94352314]])

# %%
X_train = []
y_train = []
type(X_train)
training_set_scaled[60-60:60, 0]
# Out:
# array([0.19609217, 0.20619311, 0.21022789, 0.20751095, 0.21069257,
#        0.20338729, 0.20495144, 0.2075338 , 0.21043865, 0.1997537 ,
#        0.20709198, 0.21062909, 0.19908335, 0.20311052, 0.20259506,
#        0.20068558, 0.20042405, 0.19987558, 0.19740748, 0.20400686,
#        0.20901416, 0.20649781, 0.20580969, 0.20465435, 0.20152098,
#        0.18982035, 0.19484543, 0.18708056, 0.18550371, 0.18330223,
#        0.18499333, 0.18974418, 0.18851013, 0.18260903, 0.18609027,
#        0.1858135 , 0.19154447, 0.18315242, 0.16940265, 0.17425506,
#        0.1679096 , 0.16220656, 0.16851901, 0.14444995, 0.14355361,
#        0.15002349, 0.16164032, 0.15948962, 0.16861042, 0.17941218,
#        0.17581667, 0.16763283, 0.15660763, 0.16677966, 0.15187964,
#        0.15781375, 0.14235511, 0.13188599, 0.13136799, 0.13400622])

# %%
X_train = []
y_train = []
type(X_train)
for i in range(60, 1482):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
#np.expand_dims(X_train,)
X_train.shape
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

# %%
#Compiling and fitting the model
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 45/45 [==============================] - 7s 59ms/step - loss: 0.0049
# Epoch 2/100
# 45/45 [==============================] - 3s 57ms/step - loss: 0.0031
# Epoch 3/100
# 45/45 [==============================] - 3s 60ms/step - loss: 0.0027
# Epoch 4/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0028
# Epoch 5/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0027
# Epoch 6/100
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0029
# Epoch 7/100
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0027
# Epoch 8/100
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0026
# Epoch 9/100
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0026
# Epoch 10/100
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0029
# Epoch 11/100
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0026
# Epoch 12/100
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0023
# Epoch 13/100
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0022
# Epoch 14/100
# 45/45 [==============================] - 3s 61ms/step - loss: 0.0027
# Epoch 15/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0020
# Epoch 16/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0022
# Epoch 17/100
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0020
# Epoch 18/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0023
# Epoch 19/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0019
# Epoch 20/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0019
# Epoch 21/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0020
# Epoch 22/100
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0018
# Epoch 23/100
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0019
# Epoch 24/100
# 45/45 [==============================] - 3s 61ms/step - loss: 0.0019
# Epoch 25/100
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0018
# Epoch 26/100
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0018
# Epoch 27/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0017
# Epoch 28/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0017
# Epoch 29/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0017
# Epoch 30/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0017
# Epoch 31/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0014
# Epoch 32/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0015
# Epoch 33/100
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0016
# Epoch 34/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0016
# Epoch 35/100
# 45/45 [==============================] - 3s 60ms/step - loss: 0.0015
# Epoch 36/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0015
# Epoch 37/100
# 45/45 [==============================] - 3s 60ms/step - loss: 0.0015
# Epoch 38/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0014
# Epoch 39/100
# 45/45 [==============================] - 3s 61ms/step - loss: 0.0014
# Epoch 40/100
# 45/45 [==============================] - 3s 61ms/step - loss: 0.0016
# Epoch 41/100
# 45/45 [==============================] - 3s 61ms/step - loss: 0.0015
# Epoch 42/100
# 45/45 [==============================] - 3s 60ms/step - loss: 0.0015
# Epoch 43/100
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0015
# Epoch 44/100
# 45/45 [==============================] - 3s 60ms/step - loss: 0.0014
# Epoch 45/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0013
# Epoch 46/100
# 45/45 [==============================] - 3s 61ms/step - loss: 0.0012
# Epoch 47/100
# 45/45 [==============================] - 3s 61ms/step - loss: 0.0013
# Epoch 48/100
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0015
# Epoch 49/100
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0014
# Epoch 50/100
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0013
# Epoch 51/100
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0013
# Epoch 52/100
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0011
# Epoch 53/100
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0012
# Epoch 54/100
# 45/45 [==============================] - 3s 67ms/step - loss: 0.0013
# Epoch 55/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0011
# Epoch 56/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0013
# Epoch 57/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0015
# Epoch 58/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0012
# Epoch 59/100
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0012
# Epoch 60/100
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0011
# Epoch 61/100
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0012
# Epoch 62/100
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0011
# Epoch 63/100
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0011
# Epoch 64/100
# 45/45 [==============================] - 3s 67ms/step - loss: 0.0011
# Epoch 65/100
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0011
# Epoch 66/100
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0012
# Epoch 67/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0012
# Epoch 68/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0011
# Epoch 69/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0012
# Epoch 70/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0012
# Epoch 71/100
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0010
# Epoch 72/100
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0011
# Epoch 73/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0011
# Epoch 74/100
# 45/45 [==============================] - 3s 63ms/step - loss: 8.7840e-04
# Epoch 75/100
# 45/45 [==============================] - 3s 59ms/step - loss: 0.0012
# Epoch 76/100
# 45/45 [==============================] - 3s 58ms/step - loss: 0.0012
# Epoch 77/100
# 45/45 [==============================] - 3s 58ms/step - loss: 9.2616e-04
# Epoch 78/100
# 45/45 [==============================] - 3s 59ms/step - loss: 0.0010
# Epoch 79/100
# 45/45 [==============================] - 3s 59ms/step - loss: 9.1968e-04
# Epoch 80/100
# 45/45 [==============================] - 3s 60ms/step - loss: 9.4405e-04
# Epoch 81/100
# 45/45 [==============================] - 3s 65ms/step - loss: 9.7165e-04
# Epoch 82/100
# 45/45 [==============================] - 3s 61ms/step - loss: 9.9800e-04
# Epoch 83/100
# 45/45 [==============================] - 3s 60ms/step - loss: 9.9565e-04
# Epoch 84/100
# 45/45 [==============================] - 3s 59ms/step - loss: 0.0010
# Epoch 85/100
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0010
# Epoch 86/100
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0010
# Epoch 87/100
# 45/45 [==============================] - 3s 67ms/step - loss: 9.3853e-04
# Epoch 88/100
# 45/45 [==============================] - 3s 62ms/step - loss: 9.1716e-04
# Epoch 89/100
# 45/45 [==============================] - 3s 61ms/step - loss: 9.8509e-04
# Epoch 90/100
#  5/45 [==>...........................] - ETA: 2s - loss: 9.5811e-04

# %%
#Fetching the test data and preprocessing
testdataframe = gh(symbol='BANKNIFTY',start=dt.datetime(2019,1,1),end=dt.datetime(2019,9,18),index=True)
testdataframe['Date'] = testdataframe.index
testdata = pd.DataFrame(columns = ['Date', 'Open', 'High', 'Low', 'Close'])
testdata['Date'] = testdataframe['Date']
testdata['Open'] = testdataframe['Open']
testdata['High'] = testdataframe['High']
testdata['Low'] = testdataframe['Low']
testdata['Close'] = testdataframe['Close']
real_stock_price = testdata.iloc[:, 1:2].values
dataset_total = pd.concat((data2['Open'], testdata['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(testdata) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 235):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

#Making predictions on the test data
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

#Visualizing the prediction
plt.figure(figsize=(20,10))
plt.plot(real_stock_price, color = 'green', label = 'BankNifty Index Price')
plt.plot(predicted_stock_price, color = 'red', label = 'Predicted Bank Nifty Index Price')
plt.title('Bank Nifty Index Price Prediction')
plt.xlabel('Trading Day')
plt.ylabel('Bank Nifty Index Price')
plt.legend()
plt.show()
